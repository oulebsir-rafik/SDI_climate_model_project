# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from statsmodels.tsa.seasonal import seasonal_decompose
from statsmodels.graphics.tsaplots import plot_acf, plot_pacf

# %%
# read the necessary data
rawdata = pd.read_csv('./data/clean/clean_data.csv')
# convert the date column to datetime format
# format="mixed" parses each value independently (the column mixes dd/mm/yyyy and
# dd/mm/yy, e.g. some days in Oct-Dec 2024 use a 2-digit year); inferring a single
# format for the whole column would silently coerce mismatched rows to NaT and drop
# them in the groupby below.
rawdata["DATE"] = pd.to_datetime(rawdata["DATE"], format="mixed", dayfirst=True, errors='coerce')
# turn all column into numeric, except the date  and heure columns
for col in rawdata.columns:
    if col not in ['DATE', 'HEURE']:
        rawdata[col] = pd.to_numeric(rawdata[col], errors='coerce')

# replace Heure values by categories
# 8h00 is the morning, 10h30 or 10h00 is midday, 14h00 or 15h30 is the afternoon.
def categorize_heure(heure):
    if pd.isna(heure):
        return np.nan
    else:
        heure = str(heure).strip()  # Remove any leading/trailing whitespace
        if heure in ['8h00', '8h30']:
            return 'morning'
        elif heure in ['10h00', '10h30']:
            return 'midday'
        elif heure in ['14h00', '15h00', '15h30']:
            return 'afternoon'
        else:
            return 'unknown'
rawdata['HEURE'] = rawdata['HEURE'].apply(categorize_heure)

# avergae the values of the same day
avgdata = rawdata.drop(columns=['HEURE']).groupby('DATE').mean().reset_index()

# %% [markdown]
# ## Cartridge Filter

# %%
# select column that have CF in their name
CF_data = avgdata[['DATE'] + [col for col in avgdata.columns if 'CF' in col]]
CF_data.head()
# Out:
#         DATE  Ph_O_CF_A  Température_O_CF_A  Conductivité_O_CF_A  TDS_O_CF_A  \
# 0 2024-01-01   8.100000           17.666667                 55.0       33.00
# 1 2024-01-02   8.086667           17.200000                 55.0       33.00
# 2 2024-01-03   8.106667           17.266667                 55.0       33.00
# 3 2024-01-04   8.176667           16.533333                 55.1       33.06
# 4 2024-01-05        NaN                 NaN                  NaN         NaN
#
#    Turbidité_O_CF_A  Ph_O_CF_B  Température_O_CF_B  Conductivité_O_CF_B  \
# 0          0.013333   8.100000           17.666667                 55.0
# 1          0.010000   8.086667           17.200000                 55.0
# 2          0.010000   8.106667           17.266667                 55.0
# 3          0.010000   7.553333           16.733333                 55.1
# 4               NaN        NaN                 NaN                  NaN
#
#    TDS_O_CF_B  Turbidité_O_CF_B
# 0       33.00              0.02
# 1       33.00              0.01
# 2       33.00              0.01
# 3       33.06              0.01
# 4         NaN               NaN

# %% [markdown]
# #### Descriptive Statistics

# %%
CF_data.describe()
# Out:
#                       DATE   Ph_O_CF_A  Température_O_CF_A  \
# count                  346  312.000000          311.000000
# mean   2024-07-06 00:00:00    8.020919           19.899196
# min    2024-01-01 00:00:00    7.830000           15.666667
# 25%    2024-03-29 06:00:00    7.980000           17.100000
# 50%    2024-06-29 12:00:00    8.010000           19.300000
# 75%    2024-09-29 18:00:00    8.050833           22.550000
# max    2025-01-31 00:00:00    8.276667           27.200000
# std                    NaN    0.067673            3.018786
#
#        Conductivité_O_CF_A  TDS_O_CF_A  Turbidité_O_CF_A   Ph_O_CF_B  \
# count           311.000000  307.000000        312.000000  307.000000
# mean             54.230268   36.088472          0.013958    8.017286
# min              53.000000   31.420000          0.000000    7.380000
# 25%              53.700000   32.940000          0.000000    7.971667
# 50%              54.100000   37.380000          0.000000    8.010000
# 75%              54.650000   37.730000          0.000000    8.050000
# max              56.200000   39.340000          0.660000    8.400000
# std               0.783138    2.376882          0.050344    0.082703
#
#        Température_O_CF_B  Conductivité_O_CF_B  TDS_O_CF_B  Turbidité_O_CF_B
# count          306.000000           306.000000  303.000000        307.000000
# mean            19.908137            54.222876   35.866870          0.011906
# min             15.700000            53.000000   32.000000          0.000000
# 25%             17.075000            53.700000   32.865000          0.000000
# 50%             19.325000            54.083333   37.310000          0.000000
# 75%             22.600000            54.625000   37.730000          0.000000
# max             27.200000            56.200000   39.340000          0.420000
# std              3.023200             0.775478    2.479103          0.036454

# %%
# boxplot of CF data
n_cols = 5
n_rows = -(-((len(CF_data.columns) - 1)) // n_cols)  # ceiling division
fig, axes = plt.subplots(n_rows, n_cols, figsize=(20, 5 * n_rows))
axes = axes.flatten()
for ax, col in zip(axes, CF_data.columns[1:]):
    sns.violinplot(y=CF_data[col], ax=ax)
    ax.set_title(col)
for ax in axes[len(CF_data.columns) - 1:]:
    ax.axis('off')
plt.tight_layout()
plt.show()

# %% [markdown]
# #### Temporal Evolution of the data

# %%
for col in CF_data.columns:
    if col != 'DATE':
        plt.figure(figsize=(14, 5))
        plt.plot(CF_data['DATE'], CF_data[col], marker='o')
        plt.title(f'Time Series of {col}')
        plt.xlabel('Date')
        plt.ylabel(col)
        plt.grid()
        plt.show()

# %% [markdown]
# #### Visualtion of the relationship between variables

# %%
sns.pairplot(CF_data.iloc[:, 1:])

# %%
# calculate the correlation matrix using Pearson correlation, spearman correlation, and Kendall correlation
correlation_methods = ['pearson', 'spearman', 'kendall']
for method in correlation_methods:
    corr_matrix = CF_data.iloc[:, 1:].corr(method=method)
    plt.figure(figsize=(10, 8))
    sns.heatmap(corr_matrix, annot=True, cmap='coolwarm', fmt=".2f")
    plt.title(f'Correlation Matrix ({method.capitalize()} method)')
    plt.show()

# %% [markdown]
# #### Time series features analysis

# %%
# ACF and PACF for each CF variable
for col in CF_data.columns[1:]:
    plot_acf(CF_data[col].dropna(), lags=10)
    plt.title(f'ACF of {col}')
    plt.show()

    plot_pacf(CF_data[col].dropna(), lags=10)
    plt.title(f'PACF of {col}')
    plt.show()

# %%
# time series decomposition for each CF variable

for col in CF_data.columns[1:]:
    decomp = seasonal_decompose(CF_data[col].dropna(), model='additive', period=12)
    plt.figure(figsize=(12, 8))
    plt.suptitle(f'Time Series Decomposition of {col}', fontsize=16)
    plt.subplot(411)
    plt.plot(decomp.observed, label='Observed')
    plt.legend(loc='upper left')
    plt.subplot(412)
    plt.plot(decomp.trend, label='Trend', color='orange')
    plt.legend(loc='upper left')
    plt.subplot(413)
    plt.plot(decomp.seasonal, label='Seasonal', color='green')
    plt.legend(loc='upper left')
    plt.subplot(414)
    plt.plot(decomp.resid, label='Residual', color='red')
    plt.legend(loc='upper left')
    plt.tight_layout(rect=[0, 0, 1, 0.96])
